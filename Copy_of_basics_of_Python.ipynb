# %% [markdown]
# <a href="https://colab.research.google.com/github/marineeconomist/ProgrammingAssignment2/blob/master/Copy_of_basics_of_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Basic concepts**

# %%
a=2+2
print(a)
type(a)
# Out:
# 4
# int

# %%
type(a)
# Out:
# float

# %%
b=5.4
print(b)
type(b)
# Out:
# 5.4
# float

# %%
type(b)
# Out:
# int

# %%
c = 'python'
print(c)
type(c)
# Out:
# python
# str

# %% [markdown]
# ### Data Type Conversion

# %%
# convert data integer to float
a =float(a)
print(a)
type (a)
# Out:
# 4.0
# float

# %%
# Convert float to interger
b = int(b)
print(b)
type (b)
# Out:
# 5
# int

# %%
c = "400102"
type(c)
# Out:
# str

# %%
c= int(c)
print(c)
type(c)
# Out:
# 400102
# int

# %%
d = "python"
d=int(d)
print(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3261495101.py in <cell line: 0>()
#       1 d = "python"
# ----> 2 d=int(d)
#       3 print(d)
#
# ValueError: invalid literal for int() with base 10: 'python'

# %%
e = 7+3i
# Out:
#   File "/tmp/ipython-input-1261746099.py", line 1
#     e = 7+3i
#           ^
# SyntaxError: invalid decimal literal

# %%
e = 7+3j
print(e)
type(e)
# Out:
# (7+3j)
# complex
